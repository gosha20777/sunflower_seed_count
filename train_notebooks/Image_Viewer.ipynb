# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            image_path = os.path.join(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)
            print(image_path)

        # Calculate the size and adjusted display size
        max_width = 500
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = '/home/gosha20777/files/datasets/sunflower_data/images/coco_test/annotations.json'
image_dir = '/home/gosha20777/files/datasets/sunflower_data/images/coco_test/'

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   description: None
#   url: None
#   version: None
#   year: 2020
#   contributor: None
#   date_created: 2020-08-13 16:09:37.597224
# ERROR: description should be type <class 'str'>
# ERROR: url should be type <class 'str'>
# ERROR: version should be type <class 'str'>
# ERROR: contributor should be type <class 'str'>
#
# Licenses:
# =========
#   url: None
#   id: 0
#   name: None
# ERROR: url should be type <class 'str'>
# ERROR: name should be type <class 'str'>
#
#
# Categories:
# =========
#   super_category: None
#     id 0: _background_
#     id 1: 1

# %%
html = coco_dataset.display_image(3, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   license: 0
#   url: None
#   file_name: JPEGImages/20190731_091707.jpg
#   height: 4128
#   width: 3096
#   date_captured: None
#   id: 3
# /home/gosha20777/files/datasets/sunflower_data/images/coco_test/JPEGImages/20190731_091707.jpg
#   segmentations (450):
#     1189:blue:{'supercategory': None, 'id': 1, 'name': '1'}
#     1190:purple:{'supercategory': None, 'id': 1, 'name': '1'}
#     1191:red:{'supercategory': None, 'id': 1, 'name': '1'}
#     1192:green:{'supercategory': None, 'id': 1, 'name': '1'}
#     1193:orange:{'supercategory': None, 'id': 1, 'name': '1'}
#     1194:salmon:{'supercategory': None, 'id': 1, 'name': '1'}
#     1195:pink:{'supercategory': None, 'id': 1, 'name': '1'}
#     1196:gold:{'supercategory': None, 'id': 1, 'name': '1'}
#     1197:orchid:{'supercategory': None, 'id': 1, 'name': '1'}
#     1198:slateblue:{'supercategory': None, 'id': 1, 'name': '1'}
#     1199:limegreen:{'supercategory': None, 'id': 1, 'name': '1'}
#     1200:seagreen:{'supercategory': None, 'id': 1, 'name': '1'}
#     1201:darkgreen:{'supercategory': None, 'id': 1, 'name': '1'}
#     1202:olive:{'supercategory': None, 'id': 1, 'name': '1'}
#     1203:teal:{'supercategory': None, 'id': 1, 'name': '1'}
#     1204:aquamarine:{'supercategory': None, 'id': 1, 'name': '1'}
#     1205:steelblue:{'supercategory': None, 'id': 1, 'name': '1'}
#     1206:powderblue:{'supercategory': None, 'id': 1, 'name': '1'}
#     1207:dodgerblue:{'supercategory': None, 'id': 1, 'name': '1'}
#     1208:navy:{'supercategory': None, 'id': 1, 'name': '1'}
#     1209:magenta:{'supercategory': None, 'id': 1, 'name': '1'}
#     1210:sienna:{'supercategory': None, 'id': 1, 'name': '1'}
#     1211:maroon:{'supercategory': None, 'id': 1, 'name': '1'}
#     1212:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1213:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1214:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1215:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1216:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1217:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1218:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1219:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1220:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1221:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1222:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1223:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1224:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1225:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1226:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1227:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1228:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1229:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1230:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1231:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1232:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1233:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1234:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1235:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1236:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1237:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1238:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1239:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1240:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1241:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1242:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1243:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1244:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1245:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1246:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1247:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1248:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1249:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1250:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1251:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1252:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1253:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1254:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1255:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1256:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1257:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1258:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1259:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1260:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1261:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1262:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1263:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1264:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1265:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1266:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1267:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1268:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1269:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1270:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1271:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1272:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1273:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1274:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1275:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1276:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1277:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1278:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1279:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1280:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1281:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1282:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1283:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1284:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1285:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1286:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1287:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1288:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1289:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1290:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1291:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1292:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1293:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1294:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1295:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1296:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1297:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1298:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1299:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1300:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1301:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1302:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1303:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1304:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1305:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1306:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1307:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1308:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1309:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1310:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1311:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1312:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1313:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1314:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1315:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1316:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1317:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1318:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1319:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1320:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1321:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1322:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1323:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1324:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1325:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1326:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1327:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1328:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1329:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1330:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1331:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1332:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1333:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1334:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1335:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1336:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1337:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1338:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1339:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1340:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1341:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1342:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1343:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1344:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1345:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1346:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1347:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1348:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1349:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1350:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1351:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1352:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1353:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1354:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1355:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1356:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1357:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1358:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1359:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1360:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1361:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1362:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1363:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1364:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1365:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1366:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1367:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1368:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1369:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1370:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1371:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1372:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1373:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1374:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1375:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1376:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1377:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1378:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1379:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1380:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1381:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1382:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1383:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1384:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1385:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1386:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1387:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1388:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1389:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1390:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1391:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1392:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1393:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1394:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1395:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1396:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1397:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1398:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1399:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1400:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1401:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1402:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1403:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1404:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1405:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1406:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1407:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1408:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1409:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1410:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1411:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1412:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1413:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1414:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1415:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1416:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1417:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1418:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1419:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1420:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1421:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1422:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1423:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1424:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1425:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1426:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1427:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1428:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1429:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1430:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1431:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1432:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1433:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1434:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1435:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1436:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1437:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1438:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1439:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1440:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1441:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1442:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1443:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1444:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1445:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1446:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1447:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1448:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1449:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1450:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1451:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1452:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1453:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1454:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1455:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1456:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1457:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1458:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1459:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1460:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1461:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1462:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1463:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1464:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1465:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1466:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1467:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1468:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1469:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1470:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1471:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1472:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1473:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1474:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1475:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1476:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1477:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1478:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1479:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1480:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1481:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1482:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1483:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1484:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1485:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1486:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1487:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1488:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1489:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1490:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1491:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1492:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1493:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1494:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1495:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1496:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1497:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1498:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1499:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1500:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1501:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1502:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1503:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1504:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1505:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1506:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1507:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1508:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1509:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1510:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1511:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1512:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1513:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1514:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1515:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1516:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1517:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1518:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1519:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1520:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1521:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1522:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1523:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1524:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1525:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1526:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1527:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1528:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1529:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1530:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1531:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1532:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1533:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1534:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1535:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1536:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1537:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1538:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1539:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1540:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1541:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1542:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1543:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1544:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1545:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1546:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1547:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1548:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1549:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1550:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1551:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1552:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1553:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1554:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1555:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1556:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1557:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1558:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1559:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1560:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1561:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1562:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1563:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1564:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1565:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1566:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1567:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1568:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1569:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1570:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1571:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1572:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1573:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1574:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1575:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1576:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1577:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1578:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1579:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1580:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1581:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1582:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1583:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1584:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1585:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1586:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1587:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1588:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1589:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1590:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1591:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1592:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1593:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1594:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1595:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1596:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1597:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1598:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1599:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1600:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1601:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1602:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1603:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1604:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1605:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1606:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1607:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1608:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1609:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1610:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1611:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1612:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1613:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1614:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1615:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1616:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1617:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1618:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1619:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1620:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1621:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1622:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1623:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1624:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1625:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1626:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1627:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1628:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1629:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1630:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1631:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1632:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1633:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1634:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1635:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1636:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1637:white:{'supercategory': None, 'id': 1, 'name': '1'}
#     1638:white:{'supercategory': None, 'id': 1, 'name': '1'}
# <div class="container" style="position:relative;"><img src="/home/gosha20777/files/datasets/sunflower_data/images/coco_test/JPEGImages/20190731_091707.jpg" style="position:relative;top:0px;left:0px;width:500px;"><div class="svgclass"><svg width="500" height="666.6666666666666"><polygon points="134 232 132 231 129 228 129 224 131 221 134 220 136 223 137 226 136 230" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="142 223 138 221 136 219 134 216 135 213 138 209 141 209 144 212 144 217" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="151 211 148 210 146 208 145 206 146 204 151 202 154 203 152 207" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="150 228 145 225 143 223 143 220 145 216 147 214 151 217 151 219 151 222" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="142 238 139 236 137 234 137 231 138 228 140 225 144 226 145 230 144 234" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="135 249 130 246 127 243 127 240 132 237 135 239 138 241" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="157 215 154 212 153 211 153 208 154 206 155 204 157 204 162 207 162 210
#  160 214" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="168 206 165 206 162 204 162 201 162 198 164 197 167 197 172 199 173 201
#  169 204" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="171 196 169 196 167 195 166 192 166 189 167 188 169 188 173 190 173 192
#  172 194" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="180 189 178 188 177 184 180 180 183 180 185 183 183 187" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="199 184 197 183 195 180 196 177 198 175 202 175 204 178 203 180 201 182" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="186 192 185 187 185 185 186 182 187 181 191 181 193 183 192 188 189 190" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="175 200 172 198 172 196 173 193 174 192 176 190 179 192 178 196 176 199" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="216 183 213 182 213 178 214 174 218 173 221 174 222 177 221 182" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="204 190 203 186 204 182 206 181 209 180 211 183 209 186" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="233 182 231 181 229 179 227 177 227 173 231 170 236 172 237 175 236 177
#  234 179" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="236 186 235 182 235 179 237 177 239 176 242 177 242 181 240 183 238 186
#  238 187" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="250 184 248 180 247 177 248 174 251 171 254 172 256 174 256 177 255 179
#  253 181 251 184 250 185" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="255 188 253 186 253 183 254 180 257 178 260 178 262 181 262 184 259 187
#  256 189" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="267 185 264 181 264 178 264 175 266 173 268 172 271 174 271 177 270 182" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="276 192 273 190 271 188 271 186 271 183 274 181 277 180 281 180 283 183
#  281 186 279 189" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><polygon points="180 206 177 202 177 200 178 195 180 193 184 193 187 195 187 198 185 201
#  182 206" style="fill:sienna; stroke:sienna; stroke-width:1; fill-opacity:0.5" /><polygon points="192 198 190 196 189 193 189 192 191 190 193 189 196 188 197 191 195 194
#  193 195" style="fill:maroon; stroke:maroon; stroke-width:1; fill-opacity:0.5" /><polygon points="213 195 208 193 206 189 209 187 212 183 215 184 219 185 220 188 217 193
#  216 196" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="228 192 225 190 223 189 221 186 222 184 224 182 226 181 229 181 232 183
#  234 184 231 187 230 191" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="235 198 234 197 231 195 230 194 230 192 231 188 234 186 237 189 238 191
#  238 195" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="247 197 246 194 243 193 239 191 238 189 238 186 240 184 244 181 246 182
#  248 184 250 187 251 191 249 193" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="255 202 253 199 252 197 249 196 249 195 251 191 254 189 257 191 258 193
#  258 196 256 201" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="264 197 261 194 260 192 259 190 259 188 264 184 267 185 268 187 267 193" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="268 205 268 202 267 199 268 197 268 193 270 190 272 191 274 193 274 196
#  272 200 271 202" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="171 213 169 206 170 204 173 202 176 203 176 206 173 209 171 211" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="165 223 160 220 157 216 160 214 162 211 165 208 167 210 169 215 168 218
#  166 222" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="289 186 285 183 283 180 285 174 290 171 293 173 295 177 295 180 291 183" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="303 186 302 181 300 179 299 176 301 173 303 171 307 171 308 174 309 178
#  306 182" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="317 185 314 180 312 176 314 174 317 173 320 179 318 182" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="321 189 320 185 319 182 322 179 326 178 328 182 328 184 324 187" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="334 189 332 186 330 184 331 181 336 179 339 179 340 183 340 186" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="340 197 337 196 336 193 335 190 336 188 339 187 343 186 345 187 346 190
#  346 193 344 196" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="353 201 351 199 349 194 352 190 357 188 359 191 358 195 358 198 355 201" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="359 210 356 208 354 203 356 201 360 199 363 198 364 201 366 206 364 208" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="361 220 360 212 361 211 363 209 368 207 370 209 370 212 370 216 369 219
#  364 220" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="372 221 372 216 373 212 376 211 379 211 381 212 381 216 380 220 375 221" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="380 210 380 206 382 204 385 203 386 206 387 209 387 212 382 213 381 213" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="372 211 369 207 368 203 370 202 375 201 377 201 378 204 378 207 377 210" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="368 200 367 198 367 195 370 192 373 192 375 194 376 196 374 199 371 200" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="391 217 388 214 388 211 389 209 393 208 396 209 396 213 394 215" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon points="391 222 391 218 396 216 402 215 404 216 404 220 402 222 400 224 398 225
#  393 222" style="fill:white; stroke:white; stroke-width:1; fill-opacity:0.5" /><polygon point
